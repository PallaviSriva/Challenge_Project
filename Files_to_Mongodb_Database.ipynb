# %%
import json
import pymongo 

client = pymongo.MongoClient("mongodb+srv://Pallavi:Pallavi123@atlascluster.qvv16ul.mongodb.net/?retryWrites=true&w=majority")
db=client.test
database = client['Youtube_Scraped_Data']
krish_data = database['Krish']
file_list=[]

with open('Krish_json.json') as f:
    file_data = json.load(f)

# # if pymongo < 3.0, use insert()
# collection_currency.insert(file_data)
# # if pymongo >= 3.0 use insert_one() for inserting one document
# collection_currency.insert_one(file_data)
# # if pymongo >= 3.0 use insert_many() for inserting many documents
file_list.append(file_data)
krish_data.insert_many(file_list)

client.close()

# %%
import json
import pymongo 

client = pymongo.MongoClient("mongodb+srv://Pallavi:Pallavi123@atlascluster.qvv16ul.mongodb.net/?retryWrites=true&w=majority")
db=client.test
database = client['Youtube_Scraped_Data']
krish_data = database['Hitesh']
file_list=[]

with open('Hitesh_json.json') as f:
    file_data = json.load(f)

# # if pymongo < 3.0, use insert()
# collection_currency.insert(file_data)
# # if pymongo >= 3.0 use insert_one() for inserting one document
# collection_currency.insert_one(file_data)
# # if pymongo >= 3.0 use insert_many() for inserting many documents
file_list.append(file_data)
krish_data.insert_many(file_list)

client.close()

# %%
import json
import pymongo 

client = pymongo.MongoClient("mongodb+srv://Pallavi:Pallavi123@atlascluster.qvv16ul.mongodb.net/?retryWrites=true&w=majority")
db=client.test
database = client['Youtube_Scraped_Data']
krish_data = database['Telusko']
file_list=[]

with open('Telusko_json.json') as f:
    file_data = json.load(f)

# # if pymongo < 3.0, use insert()
# collection_currency.insert(file_data)
# # if pymongo >= 3.0 use insert_one() for inserting one document
# collection_currency.insert_one(file_data)
# # if pymongo >= 3.0 use insert_many() for inserting many documents
file_list.append(file_data)
krish_data.insert_many(file_list)

client.close()

# %%
import json
import pymongo 

client = pymongo.MongoClient("mongodb+srv://Pallavi:Pallavi123@atlascluster.qvv16ul.mongodb.net/?retryWrites=true&w=majority")
db=client.test
database = client['Youtube_Scraped_Data']
krish_data = database['MySirG']
file_list=[]

with open('MySirG_json.json') as f:
    file_data = json.load(f)

# # if pymongo < 3.0, use insert()
# collection_currency.insert(file_data)
# # if pymongo >= 3.0 use insert_one() for inserting one document
# collection_currency.insert_one(file_data)
# # if pymongo >= 3.0 use insert_many() for inserting many documents
file_list.append(file_data)
krish_data.insert_many(file_list)

client.close()

# %%
import json
import pymongo 

client = pymongo.MongoClient("mongodb+srv://Pallavi:Pallavi123@atlascluster.qvv16ul.mongodb.net/?retryWrites=true&w=majority")
db=client.test
database = client['Youtube_Scraped_Data']
krish_data = database['Sourav']
file_list=[]

with open('SouravJoshi_json.json') as f:
    file_data = json.load(f)

# # if pymongo < 3.0, use insert()
# collection_currency.insert(file_data)
# # if pymongo >= 3.0 use insert_one() for inserting one document
# collection_currency.insert_one(file_data)
# # if pymongo >= 3.0 use insert_many() for inserting many documents
file_list.append(file_data)
krish_data.insert_many(file_list)

client.close()

# %%
import json
import pymongo 

client = pymongo.MongoClient("mongodb+srv://Pallavi:Pallavi123@atlascluster.qvv16ul.mongodb.net/?retryWrites=true&w=majority")
db=client.test
database = client['Youtube_Scraped_Data']
krish_data = database['Flying']
file_list=[]

with open('FlyingBeast_json.json') as f:
    file_data = json.load(f)

# # if pymongo < 3.0, use insert()
# collection_currency.insert(file_data)
# # if pymongo >= 3.0 use insert_one() for inserting one document
# collection_currency.insert_one(file_data)
# # if pymongo >= 3.0 use insert_many() for inserting many documents
file_list.append(file_data)
krish_data.insert_many(file_list)

client.close()

# %%
import json
import pymongo 

client = pymongo.MongoClient("mongodb+srv://Pallavi:Pallavi123@atlascluster.qvv16ul.mongodb.net/?retryWrites=true&w=majority")
db=client.test
database = client['Youtube_Scraped_Data']
krish_data = database['Mumbiker']
file_list=[]

with open('Mumbiker_json.json') as f:
    file_data = json.load(f)

# # if pymongo < 3.0, use insert()
# collection_currency.insert(file_data)
# # if pymongo >= 3.0 use insert_one() for inserting one document
# collection_currency.insert_one(file_data)
# # if pymongo >= 3.0 use insert_many() for inserting many documents
file_list.append(file_data)
krish_data.insert_many(file_list)

client.close()
